# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------
# Parameter Settings and Function Definitions
# ------------------------------
outdir = "/lfs/home/ioloi/lfs_dir/project_UCH/post_result/"
ship = "gj"
seasons = ["DJF", "MAM", "JJA", "SON"]  # List of seasons to loop over
n_bootstrap = 1000
threshold_percents = [90, 95]

# Global y-axis limits for plots (adjust as needed)
global_ylim_intensity   = (0, 2)    # For Normalized Intensity
global_ylim_probability = (0, 0.5)  # For Exceedance Probability
global_ylim_hazard      = (0, 0.1)  # For Hazard (Probability x Normalized Intensity)
global_ylim_return      = (0, 4)    # For Return Level (T = 30 years)

# Common y-axis labels
ylabel_intensity    = "Normalized Intensity"
ylabel_probability  = "Exceedance Probability"
ylabel_hazard       = "Hazard (Probability x Normalized Intensity)"
ylabel_return_level = "Return Level (T = 30 years)"

# ------------------------------
# Compute Thresholds Using Whole-Year Historical Data
# ------------------------------
# File paths for whole-year historical and SSP data
file_hist_year = f"/lfs/home/ioloi/lfs_dir/project_UCH/post_result/predicted_speed_hist_{ship}.nc"
file_ssp_year  = f"/lfs/home/ioloi/lfs_dir/project_UCH/post_result/predicted_speed_ssp_{ship}.nc"

# Read whole-year historical data and extract speederature
try:
    data_hist_year = xr.open_dataset(file_hist_year)
    speed_hist_year = data_hist_year['predicted_speed'].values.flatten()
except (FileNotFoundError, KeyError) as e:
    print(f"Error reading whole-year historical data: {e}")
    exit()

# Compute thresholds and dthr from whole-year historical data
thresholds_year = []
for perc in threshold_percents:
    thresh_val = np.percentile(speed_hist_year, perc)
    thresholds_year.append(thresh_val)
    print(f"Whole-year threshold for {perc}th percentile: {thresh_val:.4f}")

dthr = np.max(speed_hist_year) - np.min(speed_hist_year)
print(f"Whole-year dthr (Range: max - min): {dthr:.4f}")

# ------------------------------
# Define Calculation Functions
# ------------------------------
def calc_metrics(data, threshold, dthr):
    """
    Calculate risk metrics using the raw data distribution.
    """
    mask = data > threshold
    n_total = len(data)
    n_exceed = np.sum(mask)
    if n_exceed == 0:
        return 0, np.nan, 0
    exceedance_prob = n_exceed / n_total
    intensity = np.mean(data[mask]) / dthr if dthr != 0 else np.nan
    hazard = exceedance_prob * intensity
    return exceedance_prob, intensity, hazard

def bootstrap_metrics(data, threshold, dthr, n_bootstrap=1000):
    """
    Compute the distribution of risk metrics using bootstrap resampling.
    """
    boot_probs = []
    boot_intensities = []
    boot_hazards = []
    n = len(data)
    for i in range(n_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        prob, inten, haz = calc_metrics(sample, threshold, dthr)
        if np.isnan(inten):
            continue
        boot_probs.append(prob)
        boot_intensities.append(inten)
        boot_hazards.append(haz)
    if len(boot_probs) == 0:
        return (0, 0), (np.nan, 0), (0, 0)
    
    boot_probs = np.array(boot_probs)
    boot_intensities = np.array(boot_intensities)
    boot_hazards = np.array(boot_hazards)
    
    def summary(arr):
        mean_val = np.mean(arr)
        ci_lower = np.percentile(arr, 2.5)
        ci_upper = np.percentile(arr, 97.5)
        err = (ci_upper - ci_lower) / 2
        return mean_val, err

    return summary(boot_probs), summary(boot_intensities), summary(boot_hazards)

def calc_return_level(data, T):
    """
    Calculate the return level for a given return period T.
    """
    quantile_level = (1 - 1/T) * 100
    return np.percentile(data, quantile_level)

def bootstrap_return_level(data, T, n_bootstrap=1000):
    """
    Compute the distribution of return levels using bootstrap resampling.
    """
    boot_levels = []
    n = len(data)
    for i in range(n_bootstrap):
        sample = np.random.choice(data, size=n, replace=True)
        level = calc_return_level(sample, T)
        boot_levels.append(level)
    boot_levels = np.array(boot_levels)
    mean_level = np.mean(boot_levels)
    ci_lower = np.percentile(boot_levels, 2.5)
    ci_upper = np.percentile(boot_levels, 97.5)
    err = (ci_upper - ci_lower) / 2
    return mean_level, err

def replace_nan(arr):
    """Utility to replace NaNs with zeros."""
    return np.nan_to_num(arr, nan=0)

# ------------------------------
# Loop Over Seasons and Perform Analysis
# ------------------------------
for seas in seasons:
    print(f"\n--- Processing Season: {seas} ---")
    
    # File paths for seasonal historical and SSP speederature data
    file_hist = f"/lfs/home/ioloi/lfs_dir/project_UCH/post_result/predicted_speed_hist_{ship}.{seas}.nc"
    file_ssp  = f"/lfs/home/ioloi/lfs_dir/project_UCH/post_result/predicted_speed_ssp_{ship}.{seas}.nc"

    # Read seasonal netCDF files
    try:
        data_hist = xr.open_dataset(file_hist)
        data_ssp  = xr.open_dataset(file_ssp)
    except FileNotFoundError as e:
        print(f"Error for season {seas}: {e}")
        continue

    # Extract speederature data (assumed variable: 'predicted_speed')
    try:
        speed_hist = data_hist['predicted_speed'].values.flatten()
        speed_ssp  = data_ssp['predicted_speed'].values.flatten()
        print("Seasonal speederature data successfully extracted.")
    except KeyError as e:
        print(f"Error for season {seas}: Variable 'predicted_speed' not found. {e}")
        continue

    # ------------------------------
    # Analysis for speederature (Risk Metrics) Using Whole-Year Thresholds
    # ------------------------------
    results_speed = {
        'probability': {'hist': [], 'ssp': []},
        'intensity': {'hist': [], 'ssp': []},
        'hazard': {'hist': [], 'ssp': []},
        'thresholds': thresholds_year  # Use thresholds computed from whole-year data
    }

    for i, thresh_value in enumerate(thresholds_year):
        print(f"\nApplying whole-year threshold ({threshold_percents[i]}th percentile) for season {seas}: {thresh_value:.4f}")
        
        # Compute metrics for seasonal historical data
        (mean_prob_h, err_prob_h), (mean_inten_h, err_inten_h), (mean_haz_h, err_haz_h) = bootstrap_metrics(speed_hist, thresh_value, dthr, n_bootstrap)
        results_speed['probability']['hist'].append((mean_prob_h, err_prob_h))
        results_speed['intensity']['hist'].append((mean_inten_h, err_inten_h))
        results_speed['hazard']['hist'].append((mean_haz_h, err_haz_h))
        
        # Compute metrics for seasonal SSP data
        (mean_prob_s, err_prob_s), (mean_inten_s, err_inten_s), (mean_haz_s, err_haz_s) = bootstrap_metrics(speed_ssp, thresh_value, dthr, n_bootstrap)
        results_speed['probability']['ssp'].append((mean_prob_s, err_prob_s))
        results_speed['intensity']['ssp'].append((mean_inten_s, err_inten_s))
        results_speed['hazard']['ssp'].append((mean_haz_s, err_haz_s))
    
    # Print risk metric results for each threshold
    speed_labels = [f"{p}%" for p in threshold_percents]
    print("\n--- speederature Risk Metrics ---")
    for i, perc in enumerate(threshold_percents):
        thresh_value = thresholds_year[i]
        print(f"\nThreshold: {perc}th percentile (Value = {thresh_value:.4f})")
        prob_hist, prob_hist_err = results_speed['probability']['hist'][i]
        intensity_hist, intensity_hist_err = results_speed['intensity']['hist'][i]
        hazard_hist, hazard_hist_err = results_speed['hazard']['hist'][i]
        print("Historical speederature:")
        print(f"  Exceedance Probability: {prob_hist:.4f} ± {prob_hist_err:.4f}")
        print(f"  Normalized Intensity: {intensity_hist:.4f} ± {intensity_hist_err:.4f}")
        print(f"  Hazard: {hazard_hist:.4f} ± {hazard_hist_err:.4f}")
        
        prob_ssp, prob_ssp_err = results_speed['probability']['ssp'][i]
        intensity_ssp, intensity_ssp_err = results_speed['intensity']['ssp'][i]
        hazard_ssp, hazard_ssp_err = results_speed['hazard']['ssp'][i]
        print("Future SSP speederature:")
        print(f"  Exceedance Probability: {prob_ssp:.4f} ± {prob_ssp_err:.4f}")
        print(f"  Normalized Intensity: {intensity_ssp:.4f} ± {intensity_ssp_err:.4f}")
        print(f"  Hazard: {hazard_ssp:.4f} ± {hazard_ssp_err:.4f}")

    # ------------------------------
    # Analysis for speederature (Return Level for T = 30 years)
    # ------------------------------
    T = 30
    ret_level_hist, err_ret_level_hist = bootstrap_return_level(speed_hist, T, n_bootstrap)
    ret_level_ssp, err_ret_level_ssp = bootstrap_return_level(speed_ssp, T, n_bootstrap)
    print(f"\nReturn Level for T = {T} years for season {seas}:")
    print(f"  Historical: {ret_level_hist:.4f} ± {err_ret_level_hist:.4f}")
    print(f"  Future SSP: {ret_level_ssp:.4f} ± {err_ret_level_ssp:.4f}")

    # ------------------------------
    # Prepare Data for Plotting (Replace NaNs with zeros)
    # ------------------------------
    intensity_hist_means = replace_nan(np.array([val[0] for val in results_speed['intensity']['hist']]))
    intensity_hist_errs  = replace_nan(np.array([val[1] for val in results_speed['intensity']['hist']]))
    intensity_ssp_means  = replace_nan(np.array([val[0] for val in results_speed['intensity']['ssp']]))
    intensity_ssp_errs   = replace_nan(np.array([val[1] for val in results_speed['intensity']['ssp']]))
    
    prob_hist_means = replace_nan(np.array([val[0] for val in results_speed['probability']['hist']]))
    prob_hist_errs  = replace_nan(np.array([val[1] for val in results_speed['probability']['hist']]))
    prob_ssp_means  = replace_nan(np.array([val[0] for val in results_speed['probability']['ssp']]))
    prob_ssp_errs   = replace_nan(np.array([val[1] for val in results_speed['probability']['ssp']]))
    
    hazard_hist_means = replace_nan(np.array([val[0] for val in results_speed['hazard']['hist']]))
    hazard_hist_errs  = replace_nan(np.array([val[1] for val in results_speed['hazard']['hist']]))
    hazard_ssp_means  = replace_nan(np.array([val[0] for val in results_speed['hazard']['ssp']]))
    hazard_ssp_errs   = replace_nan(np.array([val[1] for val in results_speed['hazard']['ssp']]))
    
    x = np.arange(len(speed_labels))
    width = 0.35

    # ------------------------------
    # Plot Bar Charts for speederature Risk Metrics (Separate Panels)
    # ------------------------------
    fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(18, 6))
    
    axes[0].bar(x - width/2, intensity_hist_means, width, yerr=intensity_hist_errs, capsize=5, label='Historical', alpha=0.6)
    axes[0].bar(x + width/2, intensity_ssp_means, width, yerr=intensity_ssp_errs, capsize=5, label='Future SSP', alpha=0.6)
    axes[0].set_title("Normalized Intensity")
    axes[0].set_xticks(x)
    axes[0].set_xticklabels(speed_labels)
    axes[0].set_ylabel(ylabel_intensity)
    axes[0].set_ylim(global_ylim_intensity)
    axes[0].legend()
    
    axes[1].bar(x - width/2, prob_hist_means, width, yerr=prob_hist_errs, capsize=5, label='Historical', alpha=0.6)
    axes[1].bar(x + width/2, prob_ssp_means, width, yerr=prob_ssp_errs, capsize=5, label='Future SSP', alpha=0.6)
    axes[1].set_title("Exceedance Probability")
    axes[1].set_xticks(x)
    axes[1].set_xticklabels(speed_labels)
    axes[1].set_ylabel(ylabel_probability)
    axes[1].set_ylim(global_ylim_probability)
    axes[1].legend()
    
    axes[2].bar(x - width/2, hazard_hist_means, width, yerr=hazard_hist_errs, capsize=5, label='Historical', alpha=0.6)
    axes[2].bar(x + width/2, hazard_ssp_means, width, yerr=hazard_ssp_errs, capsize=5, label='Future SSP', alpha=0.6)
    axes[2].set_title("Hazard (Probability x Normalized Intensity)")
    axes[2].set_xticks(x)
    axes[2].set_xticklabels(speed_labels)
    axes[2].set_ylabel(ylabel_hazard)
    axes[2].set_ylim(global_ylim_hazard)
    axes[2].legend()
    
    plt.suptitle(f"speederature Risk Metrics for Season {seas}\n(Thresholds from Whole-Year Data, dthr from Whole-Year)", fontsize=16)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
    
    # ------------------------------
    # Plot Return Level for T = 30 years
    # ------------------------------
    fig_rl, ax_rl = plt.subplots(figsize=(8, 6))
    ax_rl.bar(0, ret_level_hist, yerr=err_ret_level_hist, capsize=10, label='Historical', alpha=0.6)
    ax_rl.bar(1, ret_level_ssp, yerr=err_ret_level_ssp, capsize=10, label='Future SSP', alpha=0.6)
    ax_rl.set_xticks([0, 1])
    ax_rl.set_xticklabels(['Historical', 'Future SSP'])
    ax_rl.set_ylabel(ylabel_return_level)
    ax_rl.set_ylim(global_ylim_return)
    ax_rl.set_title(f"Return Level for T = 30 years for Season {seas}")
    ax_rl.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Whole-year threshold for 90th percentile: 0.8386
# Whole-year threshold for 95th percentile: 0.9145
# Whole-year dthr (Range: max - min): 1.1835
#
# --- Processing Season: DJF ---
# Seasonal speederature data successfully extracted.
#
# Applying whole-year threshold (90th percentile) for season DJF: 0.8386
#
# Applying whole-year threshold (95th percentile) for season DJF: 0.9145
#
# --- speederature Risk Metrics ---
#
# Threshold: 90th percentile (Value = 0.8386)
# Historical speederature:
#   Exceedance Probability: 0.0843 ± 0.0015
#   Normalized Intensity: 0.7787 ± 0.0011
#   Hazard: 0.0656 ± 0.0012
# Future SSP speederature:
#   Exceedance Probability: 0.0856 ± 0.0015
#   Normalized Intensity: 0.7781 ± 0.0011
#   Hazard: 0.0666 ± 0.0011
#
# Threshold: 95th percentile (Value = 0.9145)
# Historical speederature:
#   Exceedance Probability: 0.0385 ± 0.0011
#   Normalized Intensity: 0.8286 ± 0.0013
#   Hazard: 0.0319 ± 0.0009
# Future SSP speederature:
#   Exceedance Probability: 0.0389 ± 0.0010
#   Normalized Intensity: 0.8278 ± 0.0012
#   Hazard: 0.0322 ± 0.0008
#
# Return Level for T = 30 years for season DJF:
#   Historical: 0.9265 ± 0.0022
#   Future SSP: 0.9274 ± 0.0021
# --- Processing Season: MAM ---
# Seasonal speederature data successfully extracted.
#
# Applying whole-year threshold (90th percentile) for season MAM: 0.8386
#
# Applying whole-year threshold (95th percentile) for season MAM: 0.9145
#
# --- speederature Risk Metrics ---
#
# Threshold: 90th percentile (Value = 0.8386)
# Historical speederature:
#   Exceedance Probability: 0.1093 ± 0.0017
#   Normalized Intensity: 0.7874 ± 0.0009
#   Hazard: 0.0861 ± 0.0014
# Future SSP speederature:
#   Exceedance Probability: 0.1124 ± 0.0016
#   Normalized Intensity: 0.7883 ± 0.0010
#   Hazard: 0.0886 ± 0.0013
#
# Threshold: 95th percentile (Value = 0.9145)
# Historical speederature:
#   Exceedance Probability: 0.0569 ± 0.0012
#   Normalized Intensity: 0.8337 ± 0.0011
#   Hazard: 0.0474 ± 0.0010
# Future SSP speederature:
#   Exceedance Probability: 0.0596 ± 0.0013
#   Normalized Intensity: 0.8332 ± 0.0010
#   Hazard: 0.0496 ± 0.0011
#
# Return Level for T = 30 years for season MAM:
#   Historical: 0.9599 ± 0.0028
#   Future SSP: 0.9626 ± 0.0026
# --- Processing Season: JJA ---
# Seasonal speederature data successfully extracted.
#
# Applying whole-year threshold (90th percentile) for season JJA: 0.8386
#
# Applying whole-year threshold (95th percentile) for season JJA: 0.9145
#
# --- speederature Risk Metrics ---
#
# Threshold: 90th percentile (Value = 0.8386)
# Historical speederature:
#   Exceedance Probability: 0.1052 ± 0.0016
#   Normalized Intensity: 0.7879 ± 0.0010
#   Hazard: 0.0829 ± 0.0013
# Future SSP speederature:
#   Exceedance Probability: 0.1030 ± 0.0016
#   Normalized Intensity: 0.7875 ± 0.0010
#   Hazard: 0.0812 ± 0.0013
#
# Threshold: 95th percentile (Value = 0.9145)
# Historical speederature:
#   Exceedance Probability: 0.0547 ± 0.0011
#   Normalized Intensity: 0.8346 ± 0.0011
#   Hazard: 0.0457 ± 0.0010
# Future SSP speederature:
#   Exceedance Probability: 0.0532 ± 0.0012
#   Normalized Intensity: 0.8342 ± 0.0012
#   Hazard: 0.0443 ± 0.0010
#
# Return Level for T = 30 years for season JJA:
#   Historical: 0.9566 ± 0.0026
#   Future SSP: 0.9540 ± 0.0021
# --- Processing Season: SON ---
# Seasonal speederature data successfully extracted.
#
# Applying whole-year threshold (90th percentile) for season SON: 0.8386
#
# Applying whole-year threshold (95th percentile) for season SON: 0.9145
#
# --- speederature Risk Metrics ---
#
# Threshold: 90th percentile (Value = 0.8386)
# Historical speederature:
#   Exceedance Probability: 0.1008 ± 0.0016
#   Normalized Intensity: 0.7832 ± 0.0010
#   Hazard: 0.0789 ± 0.0013
# Future SSP speederature:
#   Exceedance Probability: 0.1027 ± 0.0016
#   Normalized Intensity: 0.7842 ± 0.0010
#   Hazard: 0.0806 ± 0.0013
#
# Threshold: 95th percentile (Value = 0.9145)
# Historical speederature:
#   Exceedance Probability: 0.0495 ± 0.0011
#   Normalized Intensity: 0.8302 ± 0.0011
#   Hazard: 0.0411 ± 0.0009
# Future SSP speederature:
#   Exceedance Probability: 0.0513 ± 0.0012
#   Normalized Intensity: 0.8315 ± 0.0011
#   Hazard: 0.0427 ± 0.0010
#
# Return Level for T = 30 years for season SON:
#   Historical: 0.9461 ± 0.0024
#   Future SSP: 0.9499 ± 0.0024
